# %% [markdown]
# <a href="https://colab.research.google.com/github/Priyanshu01Tayal/Supervised-Learning-Practice/blob/main/Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install p7zip-full
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# p7zip-full is already the newest version (16.02+dfsg-8).
# 0 upgraded, 0 newly installed, 0 to remove and 1 not upgraded.

# %%
!7z x "archive (2).zip"
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive for archives:
#   0M Scan
# ERROR: No more files
# archive (2).zip
#
#
#
# System ERROR:
# Unknown error -2147024872

# %%
import os

os.listdir('/content/Data')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1575/4197746681.py in <cell line: 0>()
#       1 import os
#       2
# ----> 3 os.listdir('/content/Data')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/Data'
